# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# Function to read and display the CSV file with correct delimiter
def read_and_display_csv(file_path):
    # Read the CSV file using semicolon as the delimiter
    df = pd.read_csv(file_path, delimiter=';')

    # Display the names of all columns
    print("Column Names:")
    print(df.columns.tolist())

    # Display the first few rows of the dataframe
    print("\nFirst Few Rows of Data:")
    return df

# Execute the function
df= read_and_display_csv("./data/Leder.csv")
df.head()
# Out:
# Column Names:
# ['nm', 'Lederhandschuh AGKI 712 Armschutz, (M, id=5139)', 'Lederhandschuh AGKI 712 Handrücken, (M, id=5140)', 'Lederhandschuh AGKI 712 Zeigefinger, (M, id=5141)', 'Lederhandschuh AGKI 808 Armschutz, (M, id=5142)', 'Lederhandschuh AGKI 808 Handrücken, (M, id=5143)', 'Lederhandschuh AGKI 808 Zeigefinger, (M, id=5144)', 'Lederhandschuh Artelli Goliath Armschutz, (M, id=5145)', 'Lederhandschuh Artelli Goliath Mittelfinger Stoff, (M, id=5146)', 'Lederhandschuh Artelli Goliath Mittelfinger, (M, id=5147)', 'Lederhandschuh Artelli Goliath Zeigefinger, (M, id=5148)', 'Lederhandschuh kevlarverstärkt Tegera Ejendals Kevlar Handrücken, (M, id=5164)', 'Lederhandschuh kevlarverstärkt Tegera Ejendals Kevlar Zeigefinger, (M, id=5165)', 'Lederhandschuh Texxor 1141 Armschutz, (M, id=5166)', 'Lederhandschuh Texxor 1141 Handrücken, (M, id=5167)', 'Lederhandschuh Texxor 1141 Zeigefinger, (M, id=5168)', 'Lederhandschuh Texxor 1141 Finger verschmutzt von Waldarbeiten, (M, id=5175)', 'Lederhandschuh H1S1 stark verschmutzt Fiesler, (M, id=5177)', 'Lederhandschuh H1S2 stark verschmutzt Fiesler, (M, id=5178)', 'Lederhandschuh H1S3 stark verschmutzt Fiesler, (M, id=5179)', 'Lederhandschuh H2S1 stark verschmutzt Fiesler, (M, id=5180)', 'Lederhandschuh H2S2 stark verschmutzt Fiesler, (M, id=5181)', 'Lederhandschuh H2S3 stark verschmutzt Fiesler, (M, id=5182)', 'Lederhandschuh H2S4 stark verschmutzt Fiesler, (M, id=5183)', 'Lederhandschuh H3S1 stark verschmutzt Fiesler, (M, id=5184)', 'Lederhandschuh H3S2 stark verschmutzt Fiesler, (M, id=5185)', 'Lederhandschuh H3S3 stark verschmutzt Fiesler, (M, id=5186)', 'Lederhandschuh H3S4 stark verschmutzt Fiesler, (M, id=5187)', 'Lederhandschuh H3S5 stark verschmutzt Fiesler, (M, id=5188)', 'Lederhandschuh Schmersal, (M, id=6509)']
#
# First Few Rows of Data:
#     nm Lederhandschuh AGKI 712 Armschutz, (M, id=5139)  \
# 0  400                                   26,1984992233
# 1  410                                   29,9959331212
# 2  420                                   33,7222892812
# 3  430                                   35,9303612251
# 4  440                                   37,4724025626
#
#   Lederhandschuh AGKI 712 Handrücken, (M, id=5140)  \
# 0                                    30,0625957694
# 1                                    33,3494040421
# 2                                    36,5321297349
# 3                                    38,5859572941
# 4                                    39,9074494285
#
#   Lederhandschuh AGKI 712 Zeigefinger, (M, id=5141)  \
# 0                                     22,7945866574
# 1                                     22,9573521148
# 2                                     22,8823034889
# 3                                     24,0066417337
# 4                                     25,6669121811
#
#   Lederhandschuh AGKI 808 Armschutz, (M, id=5142)  \
# 0                                    36,312458887
# 1                                    39,725563885
# 2                                   42,3798819726
# 3                                   43,2887966722
# 4                                   43,6724278462
#
#   Lederhandschuh AGKI 808 Handrücken, (M, id=5143)  \
# 0                                    31,6771853019
# 1                                     34,910775667
# 2                                     37,741696825
# 3                                    39,4862462209
# 4                                    40,9211877568
#
#   Lederhandschuh AGKI 808 Zeigefinger, (M, id=5144)  \
# 0                                     25,3394079218
# 1                                     31,5122584824
# 2                                     33,8263657758
# 3                                     35,0776899701
# 4                                     37,0937144106
#
#   Lederhandschuh Artelli Goliath Armschutz, (M, id=5145)  \
# 0                                      9,49496441636
# 1                                      9,29638015324
# 2                                      8,93959380064
# 3                                      9,02915396974
# 4                                      9,32843998512
#
#   Lederhandschuh Artelli Goliath Mittelfinger Stoff, (M, id=5146)  \
# 0                                      4,60161734048
# 1                                      4,61496581698
# 2                                       4,4776757868
# 3                                       4,7031157391
# 4                                      4,77876670336
#
#   Lederhandschuh Artelli Goliath Mittelfinger, (M, id=5147)  ...  \
# 0                                      44,2156554129         ...
# 1                                      44,8745807299         ...
# 2                                      46,0329323807         ...
# 3                                      47,4027553073         ...
# 4                                      49,2849489798         ...
#
#   Lederhandschuh H2S1 stark verschmutzt Fiesler, (M, id=5180)  \
# 0                                      2,63939569108
# 1                                         2,77464305
# 2                                      3,05093649788
# 3                                       3,3967400035
# 4                                      3,63131871118
#
#   Lederhandschuh H2S2 stark verschmutzt Fiesler, (M, id=5181)  \
# 0                                      3,97403751732
# 1                                       3,8195560661
# 2                                      3,67772591456
# 3                                      3,99484347264
# 4                                      4,13100359478
#
#   Lederhandschuh H2S3 stark verschmutzt Fiesler, (M, id=5182)  \
# 0                                       1,9873170128
# 1                                      1,99318346084
# 2                                      1,91090029572
# 3                                      2,15780991572
# 4                                      2,23753264466
#
#   Lederhandschuh H2S4 stark verschmutzt Fiesler, (M, id=5183)  \
# 0                                      3,94900449004
# 1                                       4,0231788428
# 2                                      4,09051747818
# 3                                      4,33386831604
# 4                                      4,40491752634
#
#   Lederhandschuh H3S1 stark verschmutzt Fiesler, (M, id=5184)  \
# 0                                      4,26899623722
# 1                                       4,8793876048
# 2                                      5,36694881204
# 3                                      5,74724453814
# 4                                      5,96948065818
#
#   Lederhandschuh H3S2 stark verschmutzt Fiesler, (M, id=5185)  \
# 0                                         6,68826138
# 1                                      7,17941150894
# 2                                      7,54151359412
# 3                                      7,86052983208
# 4                                      8,48623532006
#
#   Lederhandschuh H3S3 stark verschmutzt Fiesler, (M, id=5186)  \
# 0                                      4,37747187772
# 1                                      4,74392848294
# 2                                       4,8205699413
# 3                                      5,13351863112
# 4                                      5,13723685296
#
#   Lederhandschuh H3S4 stark verschmutzt Fiesler, (M, id=5187)  \
# 0                                      8,54890437946
# 1                                      9,28960606846
# 2                                      9,77784905776
# 3                                      10,5043427892
# 4                                      11,0108163479
#
#   Lederhandschuh H3S5 stark verschmutzt Fiesler, (M, id=5188)  \
# 0                                      4,71150031296
# 1                                      5,05526023886
# 2                                      5,36777453502
# 3                                      5,79065389266
# 4                                      6,00901466666
#
#   Lederhandschuh Schmersal, (M, id=6509)
# 0                          45,3598657107
# 1                          52,8577731722
# 2                          55,5360101868
# 3                          56,7483466651
# 4                          58,2551598598
#
# [5 rows x 30 columns]

# %%
# Ignoring the column names except for 'nm', let's plot the data
# We'll plot the numerical values of each row as separate lines in the plot
# Assuming 'nm' is the index or a similar identifier

# Re-reading the file with the first column as index
dfL = pd.read_csv("./data/Leder.csv", delimiter=';',decimal=",", index_col=0)

# Ignoring the column names except for 'nm', let's plot the data
# We'll plot the numerical values of each row as separate lines in the plot
# Assuming 'nm' is the index or a similar identifier

# Plotting
fig, axs  = plt.subplots(3,1,figsize=(6, 8))
#plt.subplots(131)
for col in dfL.columns:
    axs[0].plot(dfL.index, dfL[col])#, label=col)

plt.xlabel('nm')
axs[0].set_ylabel('Values')
plt.title('Data Visualization')
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs[0].grid(True)
#plt.show()


# Ignoring the column names except for 'nm', let's plot the data
# We'll plot the numerical values of each row as separate lines in the plot
# Assuming 'nm' is the index or a similar identifier

# Re-reading the file with the first column as index
dfH = pd.read_csv("./data/Holz.csv", delimiter=';',decimal=",", index_col=0)

# Ignoring the column names except for 'nm', let's plot the data
# We'll plot the numerical values of each row as separate lines in the plot
# Assuming 'nm' is the index or a similar identifier

# Plotting
#plt.figure(figsize=(12, 8))

#plt.subplots(132)
for col in dfH.columns:
    axs[1].plot(dfH.index, dfH[col])#, label=col)

plt.xlabel('nm')
axs[1].set_ylabel('Values')
plt.title('Data Visualization')
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
axs[1].grid(True)
#plt.show()


# Ignoring the column names except for 'nm', let's plot the data
# We'll plot the numerical values of each row as separate lines in the plot
# Assuming 'nm' is the index or a similar identifier

# Re-reading the file with the first column as index
dfF = pd.read_csv("./data/Fleisch.csv", delimiter=';',decimal=",", index_col=0)

# Ignoring the column names except for 'nm', let's plot the data
# We'll plot the numerical values of each row as separate lines in the plot
# Assuming 'nm' is the index or a similar identifier

# Plotting
#plt.figure(figsize=(12, 8))
#fig,ax = plt.subplots(133)
for col in dfF.columns:
    axs[2].plot(dfF.index, dfF[col])#, label=col)

plt.xlabel('nm')
axs[2].set_ylabel('Values')
plt.title('Data Visualization')
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
